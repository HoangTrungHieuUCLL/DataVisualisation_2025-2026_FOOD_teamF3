# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import plotly.express as px

#Libraries for preprocessing
from gensim.parsing.preprocessing import remove_stopwords
import string
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import webcolors

#Download once if using NLTK for preprocessing
import nltk
nltk.download('punkt')

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
from fuzzywuzzy import fuzz

#Libraries for clustering
from sklearn.cluster import KMeans
# Out:
# [nltk_data] Downloading package punkt to /Users/chris/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df = pd.read_csv('view_food_clean.csv')
# Out:
# /var/folders/1p/gl48js3964n3jh2chpp0xk9c0000gn/T/ipykernel_54792/2337233985.py:1: DtypeWarning: Columns (36,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('view_food_clean.csv')

# %%
TEXT_COLS = [
    'name', 'name_search', 'remarks', 'synonyms', 'brands', 'brands_search', 'bron', 'categories'
]

# %%
# create cleaned dataframe df_2 from the columns listed in TEXT_COLS
translator_punct = str.maketrans('', '', string.punctuation)
translator_digits = str.maketrans('', '', string.digits)

def clean_text(x):
    if pd.isna(x):
        return ''
    s = str(x)
    s = remove_stopwords(s)
    s = s.translate(translator_punct)
    s = s.translate(translator_digits)
    return s.strip()

cols = [c for c in TEXT_COLS if c in df.columns]
df_2 = df[cols].applymap(clean_text)

df_2.head()
# Out:
# /var/folders/1p/gl48js3964n3jh2chpp0xk9c0000gn/T/ipykernel_54792/1642750340.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_2 = df[cols].applymap(clean_text)
#                            name                   name_search  \
# 0             Dolce Gusto Lungo             dolce gusto lungo
# 1  Dolce Gusto espresso intenso  dolce gusto espresso intenso
# 2    Dolce Gusto grande intenso    dolce gusto grande intenso
# 3        Dolce Gusto cappuccino        dolce gusto cappuccino
# 4    Dolce Gusto cappuccino ice    dolce gusto cappuccino ice
#
#                         remarks                synonyms    brands  \
# 0             Dolce Gusto Lungo                  koffie  NescafÃ©
# 1  Dolce Gusto espresso intenso         espresso koffie  NescafÃ©
# 2    Dolce Gusto grande intenso                  koffie  NescafÃ©
# 3        Dolce Gusto cappuccino  koffie koffie met melk  NescafÃ©
# 4    Dolce Gusto cappuccino ice        ijskoffie koffie  NescafÃ©
#
#   brands_search      bron categories
# 0       nescafe  NescafÃ©    dranken
# 1       nescafe  NescafÃ©    dranken
# 2       nescafe  NescafÃ©    dranken
# 3       nescafe  NescafÃ©    dranken
# 4       nescafe  NescafÃ©    dranken

# %%
# create df_3 by stemming text columns from df_2
df_3 = df_2.copy()

porter = PorterStemmer()

def stemSentence(sentence):
    if pd.isna(sentence) or sentence == '':
        return ''
    s = str(sentence)
    token_words = word_tokenize(s)
    stem_sentence = [porter.stem(word) for word in token_words]
    return ' '.join(stem_sentence)

cols_to_stem = [c for c in TEXT_COLS if c in df_3.columns]
df_3[cols_to_stem] = df_3[cols_to_stem].applymap(stemSentence)

df_3.head()
# Out:
# /var/folders/1p/gl48js3964n3jh2chpp0xk9c0000gn/T/ipykernel_54792/3223128014.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_3[cols_to_stem] = df_3[cols_to_stem].applymap(stemSentence)
#                           name                  name_search  \
# 0             dolc gusto lungo             dolc gusto lungo
# 1  dolc gusto espresso intenso  dolc gusto espresso intenso
# 2     dolc gusto grand intenso     dolc gusto grand intenso
# 3        dolc gusto cappuccino        dolc gusto cappuccino
# 4    dolc gusto cappuccino ice    dolc gusto cappuccino ice
#
#                        remarks              synonyms    brands brands_search  \
# 0             dolc gusto lungo                 koffi  nescafã©        nescaf
# 1  dolc gusto espresso intenso        espresso koffi  nescafã©        nescaf
# 2     dolc gusto grand intenso                 koffi  nescafã©        nescaf
# 3        dolc gusto cappuccino  koffi koffi met melk  nescafã©        nescaf
# 4    dolc gusto cappuccino ice        ijskoffi koffi  nescafã©        nescaf
#
#        bron categories
# 0  nescafã©    dranken
# 1  nescafã©    dranken
# 2  nescafã©    dranken
# 3  nescafã©    dranken
# 4  nescafã©    dranken

# %%
import re
from IPython.display import display

# find rows (in original df and in stemmed df_3) that contain non-ASCII / special characters

cols = [c for c in TEXT_COLS if c in df.columns]
non_ascii_re = r'[^\x00-\x7F]'

mask_df = df[cols].apply(lambda s: s.astype(str).str.contains(non_ascii_re, regex=True, na=False)).any(axis=1)
df_nonascii = df.loc[mask_df, cols + (['id'] if 'id' in df.columns else [])]

mask_df3 = df_3[cols].apply(lambda s: s.astype(str).str.contains(non_ascii_re, regex=True, na=False)).any(axis=1)
df3_nonascii = df_3.loc[mask_df3, cols]

print(f"Rows in df with non-ASCII characters: {len(df_nonascii)}")
display(df_nonascii)

print(f"\nRows in df_3 with non-ASCII characters: {len(df3_nonascii)}")
display(df3_nonascii)
# Out:
# Rows in df with non-ASCII characters: 5584
#                                                     name  \
# 0                                      Dolce Gusto Lungo
# 1                           Dolce Gusto espresso intenso
# 2                             Dolce Gusto grande intenso
# 3                                 Dolce Gusto cappuccino
# 4                             Dolce Gusto cappuccino ice
# ...                                                  ...
# 17906  MaÃ¯swafels dun sour cream and union flavour (AH)
# 17907                  AÃ¯ki rice chicken teriyaki (cup)
# 17908                   Aiki noodles Hot & Spicy XL size
# 17909                              Kaas geraspt Emmental
# 17911                           ProteÃ¯ne meerzadenbrood
#
#                                             name_search  \
# 0                                     dolce gusto lungo
# 1                          dolce gusto espresso intenso
# 2                            dolce gusto grande intenso
# 3                                dolce gusto cappuccino
# 4                            dolce gusto cappuccino ice
# ...                                                 ...
# 17906  maiswafels dun sour cream and union flavour (ah)
# 17907                  aiki rice chicken teriyaki (cup)
# 17908                  aiki noodles hot & spicy xl size
# 17909                             kaas geraspt emmental
# 17911                           proteine meerzadenbrood
#
#                                                  remarks  \
# 0                                      Dolce Gusto Lungo
# 1                           Dolce Gusto espresso intenso
# 2                             Dolce Gusto grande intenso
# 3                                 Dolce Gusto cappuccino
# 4                             Dolce Gusto cappuccino ice
# ...                                                  ...
# 17906  Galettes de mais Ã  la crÃ¨me fraÃ®che et Ã  l...
# 17907                  AÃ¯ki rice chicken teriyaki (cup)
# 17908                   Aiki noodles Hot & Spicy XL size
# 17909                            Fromage Emmental rÃ¢pÃ©
# 17911                        Pain protÃ©inÃ© multigrains
#
#                                                 synonyms        brands  \
# 0                                                 koffie      NescafÃ©
# 1                                       espresso, koffie      NescafÃ©
# 2                                                 koffie      NescafÃ©
# 3                                koffie, koffie met melk      NescafÃ©
# 4                                      ijskoffie, koffie      NescafÃ©
# ...                                                  ...           ...
# 17906               cracker, galettes de mais, maiswafel  Albert Heijn
# 17907                                                NaN         AÃ¯ki
# 17908                              noodle snack, noodles         AÃ¯ki
# 17909  emmental, emmentaler, fromage rape, gemalen ka...          Spar
# 17911                                pain, proteinebrood      Provital
#
#       brands_search      bron                     categories     id
# 0           nescafe  NescafÃ©                        dranken  24615
# 1           nescafe  NescafÃ©                        dranken  24616
# 2           nescafe  NescafÃ©                        dranken  24617
# 3           nescafe  NescafÃ©                        dranken  24618
# 4           nescafe  NescafÃ©                        dranken  24619
# ...             ...       ...                            ...    ...
# 17906  albert heijn       NaN  aardappelen en graanproducten  45476
# 17907          aiki       NaN                 bereid gerecht  45477
# 17908          aiki       NaN                 bereid gerecht  45478
# 17909          spar       NaN    melkproducten en vervangers  45479
# 17911      provital       NaN  aardappelen en graanproducten  45481
#
# [5584 rows x 9 columns]
# Rows in df_3 with non-ASCII characters: 5584
#                                              name  \
# 0                                dolc gusto lungo
# 1                     dolc gusto espresso intenso
# 2                        dolc gusto grand intenso
# 3                           dolc gusto cappuccino
# 4                       dolc gusto cappuccino ice
# ...                                           ...
# 17906  maã¯swafel dun sour cream union flavour ah
# 17907             aã¯ki rice chicken teriyaki cup
# 17908                aiki noodl hot spici xl size
# 17909                          kaa geraspt emment
# 17911                     proteã¯n meerzadenbrood
#
#                                      name_search  \
# 0                               dolc gusto lungo
# 1                    dolc gusto espresso intenso
# 2                       dolc gusto grand intenso
# 3                          dolc gusto cappuccino
# 4                      dolc gusto cappuccino ice
# ...                                          ...
# 17906  maiswafel dun sour cream union flavour ah
# 17907             aiki rice chicken teriyaki cup
# 17908               aiki noodl hot spici xl size
# 17909                         kaa geraspt emment
# 17911                     protein meerzadenbrood
#
#                                               remarks  \
# 0                                    dolc gusto lungo
# 1                         dolc gusto espresso intenso
# 2                            dolc gusto grand intenso
# 3                               dolc gusto cappuccino
# 4                           dolc gusto cappuccino ice
# ...                                               ...
# 17906  galett mai ã la crã¨me fraã®ch et ã loignon ah
# 17907                 aã¯ki rice chicken teriyaki cup
# 17908                    aiki noodl hot spici xl size
# 17909                            fromag emment rã¢pã©
# 17911                      pain protã©inã© multigrain
#
#                                                 synonyms        brands  \
# 0                                                  koffi      nescafã©
# 1                                         espresso koffi      nescafã©
# 2                                                  koffi      nescafã©
# 3                                   koffi koffi met melk      nescafã©
# 4                                         ijskoffi koffi      nescafã©
# ...                                                  ...           ...
# 17906                       cracker galett mai maiswafel  albert heijn
# 17907                                                            aã¯ki
# 17908                                  noodl snack noodl         aã¯ki
# 17909  emment emmental fromag rape gemalen kaa gerasp...          spar
# 17911                                 pain proteinebrood        provit
#
#       brands_search      bron                     categories
# 0            nescaf  nescafã©                        dranken
# 1            nescaf  nescafã©                        dranken
# 2            nescaf  nescafã©                        dranken
# 3            nescaf  nescafã©                        dranken
# 4            nescaf  nescafã©                        dranken
# ...             ...       ...                            ...
# 17906  albert heijn            aardappelen en graanproducten
# 17907          aiki                           bereid gerecht
# 17908          aiki                           bereid gerecht
# 17909          spar                 melkproducten en vervang
# 17911        provit            aardappelen en graanproducten
#
# [5584 rows x 8 columns]
